# %%
import numpy as np

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jamc88/Analisis-datos-atmosfericos/refs/heads/main/datos/rama_2023_05.csv")
df.head(15)
# Out:
#          fecha        CO         NO        NO2        NOX         O3  \
# 0   2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1   2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2   2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
# 3   2015-01-04  0.726940  24.606272  19.560976  44.165505  17.329032
# 4   2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588
# 5   2015-01-06  0.748952  27.977346  23.242718  51.213592  12.902256
# 6   2015-01-07  0.443254  11.297114  16.259762  27.594228  17.055130
# 7   2015-01-08  0.533528  10.527586  21.625862  32.155172  19.150555
# 8   2015-01-09  1.094574  41.795181  32.526678  74.283993  19.482813
# 9   2015-01-10  0.770722  23.455717  27.468599  50.919485  22.689552
# 10  2015-01-11  0.910288  22.710801  27.893728  50.623693  29.903427
# 11  2015-01-12  1.065458  27.378559  38.010050  65.428811  34.562406
# 12  2015-01-13  1.115192  30.266102  41.313559  71.577966  36.216885
# ...

# %%
df.tail(15)
# Out:
#            fecha        CO         NO        NO2        NOX         O3  \
# 3058  2023-05-17  0.492353  15.371007  24.958250  41.098280  37.183639
# 3059  2023-05-18  0.396424  10.211302  22.739479  33.773956  41.534454
# 3060  2023-05-19  0.411309   8.783163  23.767967  32.734694  38.692440
# 3061  2023-05-20  0.439638  11.730679  22.481836  34.653396  32.197115
# 3062  2023-05-21  0.262714   2.330000  14.485830  17.072500  39.044335
# 3063  2023-05-22  0.450114   9.505525  23.219731  33.585635  33.274953
# 3064  2023-05-23  0.617951  15.608586  28.610656  44.845960  34.048093
# 3065  2023-05-24  0.469238   9.140584  24.147992  34.068966  37.331148
# 3066  2023-05-25  0.376974   9.255639  20.758130  30.711779  40.973510
# 3067  2023-05-26  0.286837   5.464020  17.076152  23.230769  37.339257
# 3068  2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645
# 3069  2023-05-28  0.286826   3.458886  16.349241  20.230769  36.913761
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   3073 non-null   object
#  1   CO      3073 non-null   float64
#  2   NO      3073 non-null   float64
#  3   NO2     3073 non-null   float64
#  4   NOX     3073 non-null   float64
#  5   O3      3073 non-null   float64
#  6   PM10    3073 non-null   float64
#  7   PM25    3073 non-null   float64
#  8   SO2     3073 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 216.2+ KB

# %%
df["CO"]
# Out:
# 0       1.050696
# 1       0.807585
# 2       0.640755
# 3       0.726940
# 4       0.530815
#           ...
# 3068    0.256722
# 3069    0.286826
# 3070    0.482077
# 3071    0.441455
# 3072    0.340404
# Name: CO, Length: 3073, dtype: float64

# %%
df.columns
# Out:
# Index(['fecha', 'CO', 'NO', 'NO2', 'NOX', 'O3', 'PM10', 'PM25', 'SO2'], dtype='object')

# %%
(df['CO'].sum())/3071
# Out:
# 0.48223990853306636

# %%
df['CO'].mean()
# Out:
# 0.4819260524259833

# %%
df['CO'].median()
# Out:
# 0.4440325497287523

# %%
df['CO'].var()
# Out:
# 0.04209907680387132

# %%
df['CO'].std()
# Out:
# 0.20518059558318696

# %%
df['O3'].quantile([.25, 0.5, 0.75 ])
# Out:
# 0.25    23.923077
# 0.50    29.838384
# 0.75    36.216012
# Name: O3, dtype: float64

# %%
df['O3'].min()
# Out:
# 3.2260536398467434

# %%
df['O3'].max()
# Out:
# 67.44375

# %%
df['O3'].describe()
# Out:
# count    3073.000000
# mean       30.486331
# std         9.023384
# min         3.226054
# 25%        23.923077
# 50%        29.838384
# 75%        36.216012
# max        67.443750
# Name: O3, dtype: float64

# %%
df.describe()
# Out:
#                 CO           NO          NO2          NOX           O3  \
# count  3073.000000  3073.000000  3073.000000  3073.000000  3073.000000
# mean      0.481926    14.712425    23.030057    37.996908    30.486331
# std       0.205181     8.857507     6.754973    14.795599     9.023384
# min       0.115917     1.168000     8.061630     9.983402     3.226054
# 25%       0.327215     8.018735    18.188498    26.938073    23.923077
# 50%       0.444033    12.669596    22.421517    35.880223    29.838384
# 75%       0.597009    19.386091    26.854167    46.739777    36.216012
# max       1.831818    75.806548    72.193452   148.005952    67.443750
#
#               PM10         PM25          SO2
# count  3073.000000  3073.000000  3073.000000
# mean     41.892833    21.327371     3.689885
# std      16.047342     8.796122     3.490277
# min       8.218487     2.849315     0.630435
# 25%      29.483986    15.344720     1.557047
# 50%      40.040856    20.550000     2.484034
# ...

# %%
df.columns
# Out:
# Index(['fecha', 'CO', 'NO', 'NO2', 'NOX', 'O3', 'PM10', 'PM25', 'SO2'], dtype='object')

# %%
plt.boxplot(df['NO2'])
plt.show()

# %%
plt.boxplot(df['NO2'],vert=False)
plt.show()

# %%
plt.boxplot(df['PM10'])
plt.show()

# %%
plt.boxplot(df['PM25'])
plt.show()

# %%
import seaborn as sns

# %%
df[['PM10','PM25']]
# Out:
#             PM10       PM25
# 0     105.573684  78.953405
# 1      36.687845  15.449438
# 2      29.269022  12.915129
# 3      39.961538  16.838284
# 4      31.855643  12.667774
# ...          ...        ...
# 3068   36.774011  21.170139
# 3069   28.580000  18.454861
# 3070   30.241486  16.692857
# 3071   35.859532  20.888525
# 3072   42.203390  24.787097
#
# [3073 rows x 2 columns]

# %%
sns.boxplot(data=df[['PM10','PM25']])
plt.show()

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.boxplot(data=df, orient="h")
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['fecha', 'CO', 'NO', 'NO2', 'NOX', 'O3', 'PM10', 'PM25', 'SO2'], dtype='object')

# %%
df['NOX']>30 #me dice cuántos hay, pero no puedo sumarlos
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3068    False
# 3069    False
# 3070     True
# 3071     True
# 3072    False
# Name: NOX, Length: 3073, dtype: bool

# %%
(df['NOX']>30).sum() #todos los valores mayores a 30 sumandos
# Out:
# 2061

# %%
df['NOX'].describe()
# Out:
# count    3073.000000
# mean       37.996908
# std        14.795599
# min         9.983402
# 25%        26.938073
# 50%        35.880223
# 75%        46.739777
# max       148.005952
# Name: NOX, dtype: float64

# %%
IQR=	46.739777-26.938073

# %%
46.739777+1.5*IQR #para multiplicar algo siempre debo hacerlo con *
# Out:
# 76.44233299999999

# %%
(df['NOX']>46.739777+1.5*IQR).sum()
# Out:
# 50

# %%
50/3071*100 #porcentaje de datos arriba del límite superior
# Out:
# 1.62813415825464

# %%
df[df['NOX']>46.739777+1.5*IQR]
# Out:
#            fecha        CO         NO        NO2         NOX         O3  \
# 300   2015-10-28  1.372311  45.855556  37.611111   83.483333   9.061873
# 333   2015-11-30  1.206702  40.646893  46.649718   87.296610  31.528761
# 334   2015-12-01  1.346911  48.621687  49.959036   98.563855  32.173285
# 335   2015-12-02  1.170023  41.613744  41.537915   83.168246  34.519856
# 342   2015-12-09  1.225478  44.491765  40.176471   84.654118  20.076106
# 343   2015-12-10  1.239224  40.892086  45.414868   86.292566  28.603232
# 344   2015-12-11  1.312555  46.114486  45.605140   91.745327  27.717277
# 349   2015-12-16  1.026555  48.171021  30.389549   78.567696  21.050000
# 354   2015-12-21  1.213817  36.889412  44.056471   80.957647  25.956124
# 356   2015-12-23  1.496288  59.714617  42.396752  102.088167   8.738182
# 357   2015-12-24  1.482022  52.140957  41.811170   93.936170  28.785417
# 376   2016-01-12  1.146875  49.837054  38.783482   88.602679  13.936620
# ...

# %%
df['NOX'][df['NOX']>46.739777+1.5*IQR] #df['NOX'] es el filtro que aplico al df; [df['NOX']>46.739777+1.5*IQR]
# Out:
# 300      83.483333
# 333      87.296610
# 334      98.563855
# 335      83.168246
# 342      84.654118
# 343      86.292566
# 344      91.745327
# 349      78.567696
# 354      80.957647
# 356     102.088167
# 357      93.936170
# 376      88.602679
# 380     104.143172
# 381      78.528822
# 382      77.366292
# 385      92.643836
# 389      79.222472
# 393     148.005952
# 394     106.968137
# 398      80.320197
# 410      80.032995
# 686      91.200743
# 735      80.026030
# 736      83.161525
# 741      77.578288
# 753      77.672055
# 756      79.142045
# 1058     83.692469
# 1068     79.817610
# 1069     82.397541
# 1070     77.199153
# 1075     83.939834
# 1076     77.013889
# 1077     88.136499
# 1078    109.968900
# 1079     83.271579
# 1083     78.487696
# 1086     78.764259
# 1105     91.859406
# 1106     79.102273
# 1127     81.594595
# 1413     83.248210
# 1422     77.758621
# 1446     80.066667
# 1450     86.760135
# 1451     87.184991
# 1831     76.478528
# ...

# %%
df[['fecha','NOX']][df['NOX']>46.739777+1.5*IQR] #se aplicaron dos filtros al dataframe
# Out:
#            fecha         NOX
# 300   2015-10-28   83.483333
# 333   2015-11-30   87.296610
# 334   2015-12-01   98.563855
# 335   2015-12-02   83.168246
# 342   2015-12-09   84.654118
# 343   2015-12-10   86.292566
# 344   2015-12-11   91.745327
# 349   2015-12-16   78.567696
# 354   2015-12-21   80.957647
# 356   2015-12-23  102.088167
# 357   2015-12-24   93.936170
# 376   2016-01-12   88.602679
# 380   2016-01-16  104.143172
# 381   2016-01-17   78.528822
# 382   2016-01-18   77.366292
# 385   2016-01-21   92.643836
# 389   2016-01-25   79.222472
# 393   2016-01-29  148.005952
# 394   2016-01-30  106.968137
# 398   2016-02-03   80.320197
# 410   2016-02-15   80.032995
# 686   2016-11-17   91.200743
# 735   2017-01-05   80.026030
# 736   2017-01-06   83.161525
# 741   2017-01-11   77.578288
# 753   2017-01-23   77.672055
# 756   2017-01-26   79.142045
# 1058  2017-11-24   83.692469
# 1068  2017-12-04   79.817610
# 1069  2017-12-05   82.397541
# 1070  2017-12-06   77.199153
# ...

# %%
fig, ax=plt.subplots()
ax.plot(df["CO"])

# %%
df["fecha"]=pd.to_datetime(df["fecha"])

# %%
df=df.set_index("fecha")

# %%
fig, ax=plt.subplots()
ax.plot(df["CO"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3073 entries, 2015-01-01 to 2023-05-31
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO      3073 non-null   float64
#  1   NO      3073 non-null   float64
#  2   NO2     3073 non-null   float64
#  3   NOX     3073 non-null   float64
#  4   O3      3073 non-null   float64
#  5   PM10    3073 non-null   float64
#  6   PM25    3073 non-null   float64
#  7   SO2     3073 non-null   float64
# dtypes: float64(8)
# memory usage: 216.1 KB

# %%
df['CO']["2018":"2020"]
# Out:
# fecha
# 2018-01-01    0.375547
# 2018-01-02    0.504710
# 2018-01-03    0.541742
# 2018-01-04    0.578622
# 2018-01-05    0.536204
#                 ...
# 2020-12-27    0.433839
# 2020-12-28    0.555030
# 2020-12-29    0.623810
# 2020-12-30    0.426758
# 2020-12-31    0.230408
# Name: CO, Length: 1096, dtype: float64

# %%
df['CO']["2018-05":"2020-11"]
# Out:
# fecha
# 2018-05-01    0.248947
# 2018-05-02    0.451852
# 2018-05-03    0.425682
# 2018-05-04    0.457273
# 2018-05-05    0.239732
#                 ...
# 2020-11-26    0.520472
# 2020-11-27    0.644131
# 2020-11-28    0.658333
# 2020-11-29    0.573106
# 2020-11-30    0.340918
# Name: CO, Length: 945, dtype: float64

# %%
fig, ax=plt.subplots()
ax.plot(df["CO"]["2018":"2023"])

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=100)
ax.plot(df['PM25'], color='black',lw=0.6);
ax.tick_params(labelsize=14)
ax.set_xlabel('Tiempo', fontdict = {'fontsize':14 })
ax.set_ylabel('PM25 ($\mu$g/$m^3$)', fontdict = {'fontsize':14 });

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=100)
ax.plot(df['CO'], color='black',lw=0.6);
ax.tick_params(labelsize=14)
ax.set_xlabel('Tiempo', fontdict = {'fontsize':14 })
ax.set_ylabel('CO ($\mu$g/$m^3$)', fontdict = {'fontsize':14 });
ax.grid(True)

# %%
df['PM25']['2022-01-01':'2022-12-31'][df['PM25']>25] #df['PM25']['2022-01-01':'2022-12-31'] llama a la info, [df['PM25']>25] hace un filtro
# Out:
# fecha
# 2022-01-01    58.414835
# 2022-01-03    28.670588
# 2022-01-04    32.527687
# 2022-01-05    27.703125
# 2022-01-06    25.186747
#                 ...
# 2022-12-20    29.639394
# 2022-12-22    27.008523
# 2022-12-23    25.591549
# 2022-12-24    26.856397
# 2022-12-25    37.955224
# Name: PM25, Length: 75, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=100)
ax.plot(df['PM25']['2022-01-01':'2022-12-31'], color='black',lw=0.6);
ax.tick_params(labelsize=14)
ax.set_xlabel('Tiempo', fontdict = {'fontsize':14 })
ax.set_ylabel('CO ($\mu$g/$m^3$)', fontdict = {'fontsize':14 });
ax.axhline(25,color='red',lw=2,linestyle='--') #marca una línea en valores a partir de 25 con color rojo
ax.grid(True)
plt.show()
